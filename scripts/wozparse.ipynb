# %% [markdown]
# ### Make TMAP TRKS offset list

# %%
for t in range(0, 3525, 25):
    name = f"public byte track_{t:04d}_index;"
    print(name)
# Out:
# public byte track_0000_index;
# public byte track_0025_index;
# public byte track_0050_index;
# public byte track_0075_index;
# public byte track_0100_index;
# public byte track_0125_index;
# public byte track_0150_index;
# public byte track_0175_index;
# public byte track_0200_index;
# public byte track_0225_index;
# public byte track_0250_index;
# public byte track_0275_index;
# public byte track_0300_index;
# public byte track_0325_index;
# public byte track_0350_index;
# public byte track_0375_index;
# public byte track_0400_index;
# public byte track_0425_index;
# public byte track_0450_index;
# public byte track_0475_index;
# public byte track_0500_index;
# public byte track_0525_index;
# public byte track_0550_index;
# public byte track_0575_index;
# public byte track_0600_index;
# public byte track_0625_index;
# public byte track_0650_index;
# public byte track_0675_index;
# public byte track_0700_index;
# public byte track_0725_index;
# public byte track_0750_index;
# ...
